# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("report.csv", header=0, sep=',')
data.tail(10)
# Out:
#      year  month  day  time
# 290    23      5   21   169
# 291    23      5   22    95
# 292    23      5   23   363
# 293    23      5   24    48
# 294    23      5   25   141
# 295    23      5   26   321
# 296    23      5   27    39
# 297    23      5   28   244
# 298    23      5   29    85
# 299    23      5   30   200

# %%
data.hist(bins=50, figsize=(10,7.5))
plt.savefig('pho.png')

# %%
data["day"][data['month']==4][data['year']==23]
# Out:
# 240     1
# 241     2
# 242     3
# 243     4
# 244     5
# 245     6
# 246     7
# 247     8
# 248     9
# 249    10
# 250    11
# 251    12
# 252    13
# 253    14
# 254    15
# 255    16
# 256    17
# 257    18
# 258    19
# 259    20
# 260    21
# 261    22
# 262    23
# 263    24
# 264    25
# 265    26
# 266    27
# 267    28
# 268    29
# 269    30
# Name: day, dtype: int64

# %%
data["time"][data['month']==4][data['year']==23]
# Out:
# 240    323
# 241    365
# 242    191
# 243    311
# 244     45
# 245    399
# 246    114
# 247    197
# 248    325
# 249     42
# 250    107
# 251    305
# 252    181
# 253    234
# 254    279
# 255    314
# 256    165
# 257    148
# 258    379
# 259    143
# 260     36
# 261    285
# 262    305
# 263    359
# 264    387
# 265     86
# 266    270
# 267    230
# 268    282
# 269    248
# Name: time, dtype: int64

# %%
nd = pd.DataFrame(data["day"][data['month']==4][data['year']==22] , columns=['day'])
nd['time'] = data["time"][data['month']==4][data['year']==22]

# %%
nd.plot(kind='bar',x='day',
       y = 'time')
plt.show()
